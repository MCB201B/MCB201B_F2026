# %% [markdown]
# <h1 style="font-size: 40px; margin-bottom: 0px;">Week 1 Assignment</h1>
#
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 600px;"></hr>

# %% [markdown]
# <strong><u>Due: Saturday, September 5 at 11:59PM</u></strong>
#
# <strong><u>Total points: 4 pts</u></strong>
#
# <strong><u>To turn in your assignment:</u></strong>
# <ol>
#     <li>Update this file's name to include your lastname_firstname_ at the start of the file name.</li>
#     <li>This assignment will require you to complete the code within the indicated functions. In order to receive full credit, you must make sure that your answers are within the specified locations with proper indentation to be included as part of the function.</li>
#     <li>Any requested outputs should be contained within the notebook or within your <code>week_1_homework</code> directory on your Biology Hub server in order to be graded.</li>
#     <li>Modifications to your file or outputs after the due date will mark your assignment as late.</li>
# </ol>
#
# <strong><u>How this assignment will be graded:</u></strong>
#
# If outputs are requested, you will be graded on whether or not you have <u>all requested outputs and files</u> and if your output is correct. You will also be graded on if your code runs without errors when checked by the evaluator. There can be more than one correct way to answer a question. You can create new code cells as needed to help work through the question, but only the indicated code cells will be judged by the evaluator.
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 600px;"></hr>

# %% [markdown]
# <h2>Import any needed packages (not graded)</h2>

# %%
#Use this code cell to import any needed packages for this notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 600px;"></hr>

# %% [markdown]
# <h2>Question 1</h2>

# %% [markdown]
# 0.5pts

# %% [markdown]
# You are given a one-dimensional array <code>nums</code> of length greater than or equal to 1 containing random integers. The values of the elements within <code>nums</code> are between 0 and 100 (inclusive).
#
# Return the first element of the list if the mean of all elements in the array is greater than or equal to 50. Otherwise, return the 2nd element.
#
# You do not need to generate the random integers. The evaluator will pass arrays of random integers to the function to judge your answer. The output must be a usable output.

# %%
####################################################
## THIS CODE CELL WILL BE JUDGED BY THE EVALUATOR ##
####################################################

def question_1(nums):
    ### DO NOT MODIFY ANYTHING ABOVE THIS LINE ###
    ### YOUR ANSWER MUST BE BELOW THIS LINE WITHIN THIS CODE CELL ####
    if np.mean(nums) >= 50:
        return nums[0]
    else:
        return nums[1]

# %% [markdown]
# <strong>Test cases are below for you to test your code.</strong>

# %% [markdown]
# <h3>Test case 1</h3>
#
# <u>Input:</u>
# ```python
# nums = np.array([81, 20, 30, 64, 37,  6, 32, 92, 71, 50, 91, 93, 62, 21, 71, 14,  2,
#        38, 58, 58, 46, 65, 72, 85, 64, 21,  7, 58, 50, 11])
# ```
#
# <u>Output:</u>
# ```python
# 20
# ```
#
# <u>Explanation:</u> Because the mean of <code>nums</code> is 49 which is less than 50, we return the 2nd element.

# %%
###################
### Test case 1 ###
###################

nums = np.array([81, 20, 30, 64, 37,  6, 32, 92, 71, 50, 91, 93, 62, 21, 71, 14,  2,
       38, 58, 58, 46, 65, 72, 85, 64, 21,  7, 58, 50, 11])

question_1(nums)
# Out:
# 20

# %% [markdown]
# <h3>Test case 2</h3>
#
# <u>Input:</u>
# ```python
# nums = np.array([55, 46, 15, 75, 62])
# ```
#
# <u>Output:</u>
# ```python
# 55
# ```
#
# <u>Explanation:</u> Because the mean of <code>nums</code> is 50.6 which is greater than 50, we return the 1st element.

# %%
###################
### Test case 2 ###
###################

nums = np.array([55, 46, 15, 75, 62])

question_1(nums)
# Out:
# 55

# %% [markdown]
# <h3>Test case 3</h3>
#
# <u>Input:</u>
# ```python
# nums = np.array([ 98,  13,  69,  96,  34,  26,   7,  17,  80,  89,  50,  70,  91,
#         96,  83,  86,  54,  40,  88,   0,  10,  54,  71,  84,  15,  12,
#        100,  13,  70,  66,  80,   7,   8,  32,  95,  87,  27,  54,  49,
#         96,  71,  30,  66,   8,  30,  32,  13,  12,  16,   0,  84,   1,
#         52,  81,  56,  61,  94,  71,   2,  35,   9,  91,  71,  99,  67,
#         98,  35,  92,  86,  83,   5,   1,  48,  30,  33])
# ```
#
# <u>Output:</u>
# ```python
# 98
# ```
#
# <u>Explanation:</u> Because the mean of <code>nums</code> is 51.7333 which is greater than 50, we return the 1st element.

# %%
###################
### Test case 3 ###
###################

nums = np.array([ 98,  13,  69,  96,  34,  26,   7,  17,  80,  89,  50,  70,  91,
        96,  83,  86,  54,  40,  88,   0,  10,  54,  71,  84,  15,  12,
       100,  13,  70,  66,  80,   7,   8,  32,  95,  87,  27,  54,  49,
        96,  71,  30,  66,   8,  30,  32,  13,  12,  16,   0,  84,   1,
        52,  81,  56,  61,  94,  71,   2,  35,   9,  91,  71,  99,  67,
        98,  35,  92,  86,  83,   5,   1,  48,  30,  33])

question_1(nums)
# Out:
# 98

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 600px;"></hr>

# %% [markdown]
# <h2>Question 2</h2>

# %% [markdown]
# 0.5pts

# %% [markdown]
# You are given a list <code>nums</code> of random integers ranging between 0 and 1000 (inclusive), and a target value <code>val</code> ranging between 0 and 1000 (inclusive).
#
# Return the sum of all instances of <code>val</code> in <code>nums</code>.
#
# You do not need to generate the random integer. The evaluator will pass lists of random integers to the function to judge your answer. The output must be a usable output.

# %%
####################################################
## THIS CODE CELL WILL BE JUDGED BY THE EVALUATOR ##
####################################################

def question_2(nums, val):
    ### DO NOT MODIFY ANYTHING ABOVE THIS LINE ###
    ### YOUR ANSWER MUST BE BELOW THIS LINE WITHIN THIS CODE CELL ####
    return nums.count(val) * val

# %% [markdown]
# <strong>Test cases are below for you to test your code.</strong>

# %% [markdown]
# <h3>Test case 1</h3>
#
# <u>Input:</u>
# ```python
# nums = [45, 25, 35, 52, 76, 30, 88, 96, 96, 7, 39, 95, 16, 65, 70, 61, 64, 23, 52, 19, 33, 73, 26, 18, 39, 67, 12, 73, 25, 23, 46, 44, 46, 21, 74, 38, 29, 22, 63, 9, 86, 93, 30, 74, 41, 51, 47, 50, 51, 46, 28, 0, 14, 23, 36, 83, 53, 34, 100, 99, 55, 67, 16, 57, 68, 5, 23, 83, 56, 0, 59, 96, 46, 86, 71, 57, 86, 98, 82, 52, 96, 28, 8, 33, 94, 86, 54, 91, 75, 40, 54, 62, 49, 51, 50, 7, 84, 24, 89, 23]
#
# val = 50
#
# ```
#
# <u>Output:</u>
# ```python
# 100
# ```
#
# <u>Explanation:</u> Because there are two instances of <code>val</code> in <code>nums</code>, we return 100.

# %%
###################
### Test case 1 ###
###################

nums = [45, 25, 35, 52, 76, 30, 88, 96, 96, 7, 39, 95, 16, 65, 70, 61, 64, 
        23, 52, 19, 33, 73, 26, 18, 39, 67, 12, 73, 25, 23, 46, 44, 46, 21, 
        74, 38, 29, 22, 63, 9, 86, 93, 30, 74, 41, 51, 47, 50, 51, 46, 28, 0, 
        14, 23, 36, 83, 53, 34, 100, 99, 55, 67, 16, 57, 68, 5, 23, 83, 56, 0, 
        59, 96, 46, 86, 71, 57, 86, 98, 82, 52, 96, 28, 8, 33, 94, 86, 54, 91, 
        75, 40, 54, 62, 49, 51, 50, 7, 84, 24, 89, 23]

val = 50

question_2(nums, val)
# Out:
# 100

# %% [markdown]
# <h3>Test case 2</h3>
#
# <u>Input:</u>
# ```python
# nums = [51, 21, 38, 36, 10, 57, 17, 49, 57, 27, 55, 11, 24, 27, 35, 31, 28, 15, 43, 23, 36, 54, 40, 9, 21, 15, 22, 5, 46, 4, 58, 19, 31, 10, 7, 17, 5, 35, 18, 26, 2, 51, 2, 46, 2, 46, 10, 18, 6, 20, 38, 38, 58, 35, 35, 1, 9, 56, 21, 7, 56, 53, 54, 52, 4, 30, 43, 26, 58, 20, 15, 38, 50, 14, 39]
#
# val = 46
#
# ```
#
# <u>Output:</u>
# ```python
# 138
# ```
#
# <u>Explanation:</u> Because there are three instances of <code>val</code> in <code>nums</code>, we return 138.

# %%
###################
### Test case 2 ###
###################

nums = [51, 21, 38, 36, 10, 57, 17, 49, 57, 27, 
        55, 11, 24, 27, 35, 31, 28, 15, 43, 23, 
        36, 54, 40, 9, 21, 15, 22, 5, 46, 4, 58, 
        19, 31, 10, 7, 17, 5, 35, 18, 26, 2, 51, 
        2, 46, 2, 46, 10, 18, 6, 20, 38, 38, 58, 
        35, 35, 1, 9, 56, 21, 7, 56, 53, 54, 52, 
        4, 30, 43, 26, 58, 20, 15, 38, 50, 14, 39]

val = 46

question_2(nums, val)
# Out:
# 138

# %% [markdown]
# <h3>Test case 3</h3>
#
# <u>Input:</u>
# ```python
# nums = [21, 22, 86, 89, 65, 77, 99, 76, 85, 14, 90, 48, 16, 23, 33, 39, 79, 11, 62, 1, 84, 46, 77, 84, 11, 51, 13, 60, 21, 48, 1, 56, 16, 5, 16, 93, 40, 82, 32, 7, 14, 65, 91, 9, 31, 93, 44, 91, 96, 3, 28, 18, 16, 55, 7, 71, 48, 47, 47, 73, 9, 66, 66, 71, 8, 39, 37, 36, 90, 94, 45, 94, 52, 64, 43, 40, 10, 39, 80, 35, 83, 88, 28, 28, 73, 45, 43, 8, 31, 34, 20, 84, 71, 64, 91, 20, 63, 96, 52, 13, 75, 50, 11, 93, 52, 18, 49, 73, 10, 45, 33, 38, 47, 31, 56, 11, 21, 26, 32, 94, 42, 83, 3, 64, 43, 12, 16, 44, 91, 87, 48, 89, 83, 34, 15]
#
# val = 24
#
# ```
#
# <u>Output:</u>
# ```python
# 0
# ```
#
# <u>Explanation:</u> Because there are no instances of <code>val</code> in <code>nums</code>, we return 0.

# %%
###################
### Test case 3 ###
###################

nums = [21, 22, 86, 89, 65, 77, 99, 76, 85, 14, 90, 48, 16, 23, 33, 39, 79, 
        11, 62, 1, 84, 46, 77, 84, 11, 51, 13, 60, 21, 48, 1, 56, 16, 5, 16, 
        93, 40, 82, 32, 7, 14, 65, 91, 9, 31, 93, 44, 91, 96, 3, 28, 18, 16, 
        55, 7, 71, 48, 47, 47, 73, 9, 66, 66, 71, 8, 39, 37, 36, 90, 94, 45, 
        94, 52, 64, 43, 40, 10, 39, 80, 35, 83, 88, 28, 28, 73, 45, 43, 8, 31, 
        34, 20, 84, 71, 64, 91, 20, 63, 96, 52, 13, 75, 50, 11, 93, 52, 18, 49, 
        73, 10, 45, 33, 38, 47, 31, 56, 11, 21, 26, 32, 94, 42, 83, 3, 64, 43, 
        12, 16, 44, 91, 87, 48, 89, 83, 34, 15]

val = 24

question_2(nums, val)
# Out:
# 0

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 600px;"></hr>

# %% [markdown]
# <h2>Question 3</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# You're given your group's BCA assay results in the following directory path:
#
# <code>/home/jovyan/_shared/bcourses-1557888-readonly/week-1-homework-data/bca-assay</code>
#
# For only your group's BCA assay data, return a tidied DataFrame containing:
#
# <ul>
#     <li>Just the raw absorbance measurements for your protein standards and unknowns.</li>
#     <li>Updated column labels as floats corresponding to the protein concentration in micrograms per microliter for the protein standards, and <code>'control'</code> for your control sample and <code>'edited'</code> for your edited sample.</li>
#     <li>Replace the row labels with <code>'replicate_1'</code> and <code>'replicate_2'</code>, corresponding to your two replicates.</li>
# </ul>
#
# The evaluator will use your group's data to judge your answer. The DataFrame that you return will be judged by the evaluator. You do not need to export the DataFrame as a csv file.

# %%
####################################################
## THIS CODE CELL WILL BE JUDGED BY THE EVALUATOR ##
####################################################

def question_3(df):
    ### DO NOT MODIFY ANYTHING ABOVE THIS LINE ###
    ### YOUR ANSWER MUST BE BELOW THIS LINE WITHIN THIS CODE CELL ####

    answer = 'depends on each groups data and Benchling notebook observations'

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 600px;"></hr>

# %% [markdown]
# <h2>Question 4</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# Use your output from Question 3, and return the mean absorbances (corrected for background absorbance) as a Series. The Series needs to contain the the calculated mean values for each standard and your unknowns using your two technical replicates.
#
# The evaluator will pass the DataFrame generated from <code>question_3(df)</code> to this question's function to judge your answer for this question.

# %%
####################################################
## THIS CODE CELL WILL BE JUDGED BY THE EVALUATOR ##
####################################################

def question_4(df):
    ### DO NOT MODIFY ANYTHING ABOVE THIS LINE ###
    ### YOUR ANSWER MUST BE BELOW THIS LINE WITHIN THIS CODE CELL ####

    #Answers will depend on each group's data and labeling scheme
    return df.mean() - df.mean()[0.0]

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 600px;"></hr>

# %% [markdown]
# <h2>Question 5</h2>

# %% [markdown]
# 1pt

# %% [markdown]
# You're given a data table in the following directory path:
#
# <code>/home/jovyan/_shared/bcourses-1557888-readonly/week-1-homework-data/</code>
#
# The data table contains absorbance measurements for an MTT assay against different gene KOs and an unedited control. The absorbance measurments given in the data table are already corrected for background absorbance. The data is structured such that each biological replicate is a row and each sample condition (control and gene KOs) are columns. Column headers are structured such that the control label is <code>'Control'</code> and the gene KO labels are <code>'GENE'</code> where GENE is replaced by the gene symbol, indicating which gene was KO'ed.
#
# You are also given a list <code>genes</code> that contain gene symbols for genes that your PI has asked you to analyze. The length of the list is anywhere between 1 to 3 genes (inclusive).
#
# Return a bar plot that visualizes the mean absorbances of the control and all the gene KO lines for the genes that your PI asked you to analyze. Plot the mean absorbance values relative to the control (i.e. the control mean bar height will be 1).
#
# Your returned plot needs to contain the following:
#
# <ul>
#     <li>Appropriate X-axis labels (leaving the underscore in the label is acceptable)</li>
#     <li>Appropriate Y-axis label</li>
#     <li>Y-axis with 0 set to the origin</li>
# </ul>
#
# You do not need to generate the list of gene symbols. The evaluator will pass lists of gene symbols to your function to judge your answer and the generated output. You do not need to export the plot as a separate file.

# %%
####################################################
## THIS CODE CELL WILL BE JUDGED BY THE EVALUATOR ##
####################################################

def question_5(df, genes):
    ### DO NOT MODIFY ANYTHING ABOVE THIS LINE ###
    ### YOUR ANSWER MUST BE BELOW THIS LINE WITHIN THIS CODE CELL ####

    #Answers can differ

    subset = df[['Control'] + genes]
    
    fig, ax = plt.subplots()

    plt.bar(
        subset.columns,
        subset.mean()/subset.Control.mean(),
    )

    plt.ylim(0)
    
    ax.set_xlabel('Sample condition')
    ax.set_ylabel('Relative corrected mean absorbance')

    fig.set_dpi(300)

    sns.despine()
    
    plt.show()

# %% [markdown]
# <strong>Test cases are below for you to test your code.</strong>

# %% [markdown]
# <h3>Test case 1</h3>
#
# <u>Input:</u>
# ```python
# df = pd.read_csv('/home/jovyan/_shared/bcourses-1557888-readonly/week-1-homework-data/question_5_data.csv')
#
# genes = ['UPK3BL1', 'MIR518A2', 'SNORD3F']
#
# ```

# %%
###################
### Test case 1 ###
###################

df = pd.read_csv('/home/jovyan/_shared/bcourses-1557888-readonly/week-1-homework-data/question_5_data.csv')

genes = ['UPK3BL1', 'MIR518A2', 'SNORD3F']

question_5(df, genes)

# %% [markdown]
# <h3>Test case 2</h3>
#
# <u>Input:</u>
# ```python
# df = pd.read_csv('/home/jovyan/_shared/bcourses-1557888-readonly/week-1-homework-data/question_5_data.csv')
#
# genes = ['TRAJ7', 'WNT7B']
#
# ```

# %%
###################
### Test case 2 ###
###################

df = pd.read_csv('/home/jovyan/_shared/bcourses-1557888-readonly/week-1-homework-data/question_5_data.csv')

genes = ['TRAJ7', 'WNT7B']

question_5(df, genes)

# %% [markdown]
# <h3>Test case 3</h3>
#
# <u>Input:</u>
# ```python
# df = pd.read_csv('/home/jovyan/_shared/bcourses-1557888-readonly/week-1-homework-data/question_5_data.csv')
#
# genes = ['TCF25']
#
# ```

# %%
###################
### Test case 3 ###
###################

df = pd.read_csv('/home/jovyan/_shared/bcourses-1557888-readonly/week-1-homework-data/question_5_data.csv')

genes = ['TCF25']

question_5(df, genes)

# %% [markdown]
# <hr style="margin-left: 0px; border: 0.25px solid; border-color: #000000; width: 600px;"></hr>
